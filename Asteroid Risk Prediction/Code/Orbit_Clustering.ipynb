# %% [markdown]
# ## Asteroid orbit clustering

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
orbital_parameters = df[['a', 'e', 'i', 'om', 'w', 'q', 'ad', 'per_y']]

# %%
# Scaling the features
scaler = StandardScaler()
orbital_parameters_scaled = scaler.fit_transform(orbital_parameters)

# %%
# Applying PCA for dimensionality reduction (choose the number of components)
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
orbital_parameters_pca = pca.fit_transform(orbital_parameters_scaled)

# %%
n_clusters = 5

# %%
kmeans = KMeans(n_clusters=n_clusters, random_state=42)

# %%
df['cluster'] = cluster_labels

# %%
# Visualize the clusters in 3D space
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

for cluster_label in range(n_clusters):
    cluster_data = orbital_parameters_pca[df['cluster'] == cluster_label]
    ax.scatter(cluster_data[:, 0], cluster_data[:, 1], cluster_data[:, 2], label=f'Cluster {cluster_label}')

ax.set_xlabel('PCA Component 1')
ax.set_ylabel('PCA Component 2')
ax.set_zlabel('PCA Component 3')
plt.title('Asteroid Orbit Clustering')

plt.legend()
plt.show()

# %%
# Visualize the clusters in 2D space
plt.scatter(orbital_parameters_pca[:, 0], orbital_parameters_pca[:, 1], c=cluster_labels, cmap='rainbow')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('Asteroid Orbit Clustering (2D Visualization)')
plt.show()
